# %%
import pandas as pd
Data = pd.read_csv('/content/penguins_size.csv')
Data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# ASSIGNMENT-2

# %%
Data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
Data.dtypes
# Out:
# species               object
# island                object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
Data.body_mass_g.mean()
# Out:
# 4201.754385964912

# %%
Data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# TASK- UNIVARIATE ANALYSIS

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
Data.body_mass_g.hist()
# Out:
# <Axes: >

# %%
sns.histplot(data=Data,x="body_mass_g",color="black")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
Data.body_mass_g.skew()
# Out:
# 0.470329330480123

# %%
sns.boxplot(data=Data,x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g'>

# %%
sns.boxplot(data=Data,y="body_mass_g")
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
sns.violinplot(data=Data,x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# TASK-BI-VARIATE ANALYSIS

# %%
import matplotlib.pyplot as plt
plt.scatter(Data.culmen_length_mm, Data.culmen_depth_mm)
plt.title('length vs. depth')
plt.xlabel('length')
plt.ylabel('depth')
# Out:
# Text(0, 0.5, 'depth')

# %% [markdown]
# TASK-MULTI-VARIATE ANALYSIS

# %%
sns.kdeplot(data=Data,x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=Data,x="body_mass_g",shade=True,color="green")
# Out:
# <ipython-input-31-51ee9d3cd2c4>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=Data,x="body_mass_g",shade=True,color="green")
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.displot(data=Data,x="body_mass_g",bins=10,kde=True)

# %% [markdown]
# TASK-DESCRIPTIVE STSTISTICS

# %%
#MODE
Data["island"].mode()
# Out:
# 0    Biscoe
# Name: island, dtype: object

# %%
#mean
Data["body_mass_g"].mean()
# Out:
# 4201.754385964912

# %%
#median
Data["body_mass_g"].median()
# Out:
# 4050.0

# %%
#range
Data['body_mass_g'].max()-Data['body_mass_g'].min()
# Out:
# 3600.0

# %%
#standard deviation
round(Data['body_mass_g'].std(),2)
# Out:
# 801.95

# %% [markdown]
# CHECKING MISSING VALUES

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
		'Second Score': [30, 45, 56, np.nan],
		'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling missing value using fillna()
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %% [markdown]
# SCALING

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_data,
						columns=df.columns)
scaled_df.head()
# Out:
#    First Score  Second Score  Third Score
# 0          1.0      0.000000          NaN
# 1          0.0      0.576923     0.000000
# 2          NaN      1.000000     0.689655
# 3          0.5           NaN     1.000000

# %% [markdown]
# TASK- TRAINING AND TESTING

# %%
# import modules
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# read the dataset
Data= pd.read_csv('penguins_size.csv')

# get the locations
X = Data.iloc[:, :-1]
y = Data.iloc[:, -1]

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(
	X, y, test_size=0.05, random_state=0)
print(X_train,X_test)
print(y_train,y_test)
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 56      Adelie     Biscoe              39.0             17.5
# 15      Adelie  Torgersen              36.6             17.8
# 286     Gentoo     Biscoe              46.2             14.4
# 68      Adelie  Torgersen              35.9             16.6
# 199  Chinstrap      Dream              49.0             19.6
# ..         ...        ...               ...              ...
# 323     Gentoo     Biscoe              49.1             15.0
# 192  Chinstrap      Dream              49.0             19.5
# 117     Adelie  Torgersen              37.3             20.5
# 47      Adelie      Dream              37.5             18.9
# 172  Chinstrap      Dream              42.4             17.3
#
#      flipper_length_mm  body_mass_g
# 56               186.0       3550.0
# 15               185.0       3700.0
# 286              214.0       4650.0
# 68               190.0       3050.0
# 199              212.0       4300.0
# ...

# %% [markdown]
# TASK- MACHINELEARNING MODEL BUILDING

# %%
import pandas as pd
Data = pd.read_csv('/content/penguins_size.csv')
Data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
Data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
Data.shape
# Out:
# (344, 7)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
Data.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 3      False   False              True             True               True
# 4      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 339    False   False              True             True               True
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# ...

# %%
Data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %% [markdown]
# TASK-TRAINING THE MODEL

# %%
# import modules
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# read the dataset
Data= pd.read_csv('penguins_size.csv')

# get the locations
X = Data.iloc[:, :-1]
y = Data.iloc[:, -1]

# split the dataset
X_train, X_test, y_train, y_test = train_test_split(
	X, y, test_size=0.05, random_state=0)
print(X_train,X_test)
print(y_train,y_test)
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 56      Adelie     Biscoe              39.0             17.5
# 15      Adelie  Torgersen              36.6             17.8
# 286     Gentoo     Biscoe              46.2             14.4
# 68      Adelie  Torgersen              35.9             16.6
# 199  Chinstrap      Dream              49.0             19.6
# ..         ...        ...               ...              ...
# 323     Gentoo     Biscoe              49.1             15.0
# 192  Chinstrap      Dream              49.0             19.5
# 117     Adelie  Torgersen              37.3             20.5
# 47      Adelie      Dream              37.5             18.9
# 172  Chinstrap      Dream              42.4             17.3
#
#      flipper_length_mm  body_mass_g
# 56               186.0       3550.0
# 15               185.0       3700.0
# 286              214.0       4650.0
# 68               190.0       3050.0
# 199              212.0       4300.0
# ...
