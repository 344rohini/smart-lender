# %% [markdown]
# ASSIGNMENT-1

# %% [markdown]
# TASK-1 (Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observation))

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({'Name':['Rohini','Shanthi','Suma','Raji'],'english':[44,45,62,55],'hindi':[60,70,77,80],'Computer':[85,89,78,62],'science':[87,65,95,75]})
df
# Out:
#       Name  english  hindi  Computer  science
# 0   Rohini       44     60        85       87
# 1  Shanthi       45     70        89       65
# 2     Suma       62     77        78       95
# 3     Raji       55     80        62       75

# %% [markdown]
# TASK-2 ( Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4')

# %%
df.columns =['Name','Random_value 1','Random_value 2','Random_value 3','Random_value 4']
df
# Out:
#       Name  Random_value 1  Random_value 2  Random_value 3  Random_value 4
# 0   Rohini              44              60              85              87
# 1  Shanthi              45              70              89              65
# 2     Suma              62              77              78              95
# 3     Raji              55              80              62              75

# %% [markdown]
# TASK-3 (( Find the descriptive statistics of the 'df' dataframe.))

# %%
df.describe()
# Out:
#        Random_value 1  Random_value 2  Random_value 3  Random_value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        51.500000       71.750000       78.500000       80.500000
# std          8.582929        8.883505       11.902381       13.203535
# min         44.000000       60.000000       62.000000       65.000000
# 25%         44.750000       67.500000       74.000000       72.500000
# 50%         50.000000       73.500000       81.500000       81.000000
# 75%         56.750000       77.750000       86.000000       89.000000
# max         62.000000       80.000000       89.000000       95.000000

# %% [markdown]
# TASK-4 (Check for the null values in 'df' and find the data type of the columns)

# %%
df.isnull().any()
# Out:
# Name              False
# Random_value 1    False
# Random_value 2    False
# Random_value 3    False
# Random_value 4    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Random_value 1  4 non-null      int64
#  2   Random_value 2  4 non-null      int64
#  3   Random_value 3  4 non-null      int64
#  4   Random_value 4  4 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# TASK-5 (Display the 'Random value 2' & 'Random value 3' columns with location method and index location method.)

# %%
df.iloc[:,2:4]
# Out:
#    Random_value 2  Random_value 3
# 0              60              85
# 1              70              89
# 2              77              78
# 3              80              62

# %%
df.loc[:,'Random_value 2':'Random_value 3']
# Out:
#    Random_value 2  Random_value 3
# 0              60              85
# 1              70              89
# 2              77              78
# 3              80              62
